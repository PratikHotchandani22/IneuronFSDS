# %%
import pandas as pd

# %%
pd.read_csv("Book1.csv")
# Out:
#       name   city    rent
# 0   pratik    ngp    5400
# 1    mohit    ngp  545342
# 2  nikhil   bnglr  322432

# %%
pd.read_excel("SampleData.xlsx")
# Out:
#     OrderDate   Region       Rep     Item  Units  Unit Cost    Total
# 0  2021-01-06     East     Jones   Pencil     95       1.99   189.05
# 1  2021-01-23  Central    Kivell   Binder     50      19.99   999.50
# 2  2021-02-09  Central   Jardine   Pencil     36       4.99   179.64
# 3  2021-02-26  Central      Gill      Pen     27      19.99   539.73
# 4  2021-03-15     West   Sorvino   Pencil     56       2.99   167.44
# 5  2021-04-01     East     Jones   Binder     60       4.99   299.40
# 6  2021-04-18  Central   Andrews   Pencil     75       1.99   149.25
# 7  2021-05-05  Central   Jardine   Pencil     90       4.99   449.10
# 8  2021-05-22     West  Thompson   Pencil     32       1.99    63.68
# 9  2021-06-08     East     Jones   Binder     60       8.99   539.40
# 10 2021-06-25  Central    Morgan   Pencil     90       4.99   449.10
# 11 2021-07-12     East    Howard   Binder     29       1.99    57.71
# 12 2021-07-29     East    Parent   Binder     81      19.99  1619.19
# ...

# %%
import requests

# %%
res = requests.get("https://api.github.com/repos/pandas-dev/pandas/issues")

# %%
js = res.json()

# %%
js
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47732',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47732/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47732/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47732/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/47732',
#   'id': 1305543588,
#   'node_id': 'PR_kwDOAA0YD847cf1N',
#   'number': 47732,
#   'title': 'DOC: Updating some capitalization in doc/source/user_guide #32550',
#   'user': {'login': 'SomtochiUmeh',
#    'id': 74836691,
#    'node_id': 'MDQ6VXNlcjc0ODM2Njkx',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/74836691?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/SomtochiUmeh',
#    'html_url': 'https://github.com/SomtochiUmeh',
# ...

# %%
type(js)
# Out:
# list

# %%
d = js[0]['user']
d
# Out:
# {'login': 'SomtochiUmeh',
#  'id': 74836691,
#  'node_id': 'MDQ6VXNlcjc0ODM2Njkx',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/74836691?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/SomtochiUmeh',
#  'html_url': 'https://github.com/SomtochiUmeh',
#  'followers_url': 'https://api.github.com/users/SomtochiUmeh/followers',
#  'following_url': 'https://api.github.com/users/SomtochiUmeh/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/SomtochiUmeh/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/SomtochiUmeh/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/SomtochiUmeh/subscriptions',
#  'organizations_url': 'https://api.github.com/users/SomtochiUmeh/orgs',
#  'repos_url': 'https://api.github.com/users/SomtochiUmeh/repos',
#  'events_url': 'https://api.github.com/users/SomtochiUmeh/events{/privacy}',
# ...

# %%
pd.DataFrame(d.items())
# Out:
#                       0                                                  1
# 0                 login                                       SomtochiUmeh
# 1                    id                                           74836691
# 2               node_id                               MDQ6VXNlcjc0ODM2Njkx
# 3            avatar_url  https://avatars.githubusercontent.com/u/748366...
# 4           gravatar_id
# 5                   url          https://api.github.com/users/SomtochiUmeh
# 6              html_url                    https://github.com/SomtochiUmeh
# 7         followers_url  https://api.github.com/users/SomtochiUmeh/foll...
# 8         following_url  https://api.github.com/users/SomtochiUmeh/foll...
# 9             gists_url  https://api.github.com/users/SomtochiUmeh/gist...
# 10          starred_url  https://api.github.com/users/SomtochiUmeh/star...
# 11    subscriptions_url  https://api.github.com/users/SomtochiUmeh/subs...
# ...

# %%
pd.DataFrame(d.items(),columns=['login','id'])
# Out:
#                   login                                                 id
# 0                 login                                       SomtochiUmeh
# 1                    id                                           74836691
# 2               node_id                               MDQ6VXNlcjc0ODM2Njkx
# 3            avatar_url  https://avatars.githubusercontent.com/u/748366...
# 4           gravatar_id
# 5                   url          https://api.github.com/users/SomtochiUmeh
# 6              html_url                    https://github.com/SomtochiUmeh
# 7         followers_url  https://api.github.com/users/SomtochiUmeh/foll...
# 8         following_url  https://api.github.com/users/SomtochiUmeh/foll...
# 9             gists_url  https://api.github.com/users/SomtochiUmeh/gist...
# 10          starred_url  https://api.github.com/users/SomtochiUmeh/star...
# 11    subscriptions_url  https://api.github.com/users/SomtochiUmeh/subs...
# ...

# %%
lis =[]
for i in range(len(js)):
    lis.append(js[i]['user'])
pd.DataFrame(lis)
# Out:
#              login         id               node_id  \
# 0     SomtochiUmeh   74836691  MDQ6VXNlcjc0ODM2Njkx
# 1          GYHHAHA   41546976  MDQ6VXNlcjQxNTQ2OTc2
# 2        mroeschke   10647082  MDQ6VXNlcjEwNjQ3MDgy
# 3       twoertwein    6618166  MDQ6VXNlcjY2MTgxNjY=
# 4       twoertwein    6618166  MDQ6VXNlcjY2MTgxNjY=
# 5         JMBurley   23153616  MDQ6VXNlcjIzMTUzNjE2
# 6      daniellevie   43964549  MDQ6VXNlcjQzOTY0NTQ5
# 7         JMBurley   23153616  MDQ6VXNlcjIzMTUzNjE2
# 8       rhshadrach   45562402  MDQ6VXNlcjQ1NTYyNDAy
# 9       rhshadrach   45562402  MDQ6VXNlcjQ1NTYyNDAy
# 10        dbalabka    1269372  MDQ6VXNlcjEyNjkzNzI=
# 11        alex7088   17269774  MDQ6VXNlcjE3MjY5Nzc0
# 12    jbrockmendel    8078968  MDQ6VXNlcjgwNzg5Njg=
# 13      ahmedibrhm   81244897  MDQ6VXNlcjgxMjQ0ODk3
# 14  datapythonista   10058240  MDQ6VXNlcjEwMDU4MjQw
# 15          sebasv   10614357  MDQ6VXNlcjEwNjE0MzU3
# 16       Shadimrad   93452403          U_kgDOBZH4cw
# ...

# %%
js
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47732',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47732/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47732/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47732/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/47732',
#   'id': 1305543588,
#   'node_id': 'PR_kwDOAA0YD847cf1N',
#   'number': 47732,
#   'title': 'DOC: Updating some capitalization in doc/source/user_guide #32550',
#   'user': {'login': 'SomtochiUmeh',
#    'id': 74836691,
#    'node_id': 'MDQ6VXNlcjc0ODM2Njkx',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/74836691?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/SomtochiUmeh',
#    'html_url': 'https://github.com/SomtochiUmeh',
# ...
