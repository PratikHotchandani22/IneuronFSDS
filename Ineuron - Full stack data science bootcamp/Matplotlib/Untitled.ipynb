# %%
import pandas as pd

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
np.random.seed(20)

# %%
df = pd.DataFrame(np.random.rand(1000,1),index =pd.date_range('2022-07-21',periods=1000),columns=['data'])

# %%
df.plot()

# %%
df['data1'] = df.data.cumsum()

# %%
df['data2'] = df['data'].apply(lambda x : x * 3)

# %%
df
# Out:
#                 data       data1     data2
# 2022-07-21  0.588131    0.588131  1.764392
# 2022-07-22  0.897714    1.485845  2.693141
# 2022-07-23  0.891531    2.377375  2.674592
# 2022-07-24  0.815837    3.193213  2.447512
# 2022-07-25  0.035890    3.229102  0.107669
# ...              ...         ...       ...
# 2025-04-11  0.992189  495.812936  2.976566
# 2025-04-12  0.756037  496.568973  2.268112
# 2025-04-13  0.299186  496.868159  0.897559
# 2025-04-14  0.261712  497.129872  0.785137
# 2025-04-15  0.968979  498.098851  2.906937
#
# [1000 rows x 3 columns]

# %%
df.plot()

# %%
df1= sns.load_dataset('iris')
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
gf = df1.plot(figsize = (10,10), kind='bar')

# %%
gf.set_xlabel('index')
# Out:
# Text(0.5, 3.200000000000003, 'index')

# %%
gf

# %%
df2 = sns.load_dataset('titanic')

# %%
df2
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df2['pclass'].plot(kind = 'bar',figsize=(20,20))

# %%
df3 = pd.DataFrame(np.random.rand(10,4),columns=['a','b','c','d'])

# %%
df3.plot.bar(figsize=(10,10))

# %%
df3.plot.barh(figsize=(10,10))

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df1.plot.hist()

# %%
df1.plot.scatter(x='sepal_length',y='petal_length')

# %%
df1.plot.scatter(x='sepal_length',y='petal_length',c='petal_width')

# %%
df.plot.pie(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001FB462C5FA0>,
# ...
#       dtype=object)

# %%
iris = df1.iloc[0:3]

# %%
iris[iris.columns[0:4]]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2

# %%
iris[iris.columns[0:4]].plot.pie(subplots=True,figsize=(40,40),fontsize=40)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001FB4B9F4E80>,
# ...
#       dtype=object)

# %%
pd.plotting.scatter_matrix(df1,figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001FB4B9EA0A0>,
# ...
#       dtype=object)

# %%
# !pip install plotly

# %%
# !pip install cufflinks

# %%
from plotly.offline import iplot
import plotly as py
import plotly.tools as tls
import cufflinks as cf

# %%
py.__version__
# Out:
# '4.14.3'

# %%
df1.iplot()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\cufflinks\plotlytools.py in iplot(figure, validate, sharing, filename, online, asImage, asUrl, asPlot, dimensions, display_image, **kwargs)
#    1430                 try:
# -> 1431                         import chart_studio.plotly as py
#    1432                 except:
#
# ModuleNotFoundError: No module named 'chart_studio'
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# <ipython-input-32-f4cfec782b16> in <module>
# ----> 1 df1.iplot()
#
# ...

# %%
df2

# %%
df2.iplot(kind='scatter',x='fare',y='age',mode='markers')

# %%
df4 = pd.DataFrame(np.random.rand(100,3),columns=['a','b','c'])

# %%
df4

# %%
df4.iplot(x='a',y='b')

# %%
df4.iplot(x='a',y='b',mode='markers',xTitle='x',yTitle='y')

# %%
f2

# %%
df2

# %%
#trying to find how many males / females survived

# %%
df2.iplot(x='sex',y='survived',kind='bar')

# %%
cf.set_config_file(theme='solar')
df2.iplot(x='fare',y='age',mode='markers')

# %%
df4.iplot(kind='box')

# %%
df.rename(columns={'data' : 'a','data1':'b','data2':'c'},inplace=True)

# %%
py.offline.init_notebook_mode(connected= True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
# ...

# %%
df.iplot(x='a',y='b',z='c',kind='scatter3d')
# Out:
# <div>                            <div id="465890bc-a307-4c5b-a540-e616ec39bd58" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
